# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
def merge_Ind_Col(dataframe):
    '''
    Our data frame we read has many index columns and many headers and ti readh a data, a tuple required to reach it and this function merges and decrease the headder and index to one
    :param:dataframe: pandas.dataframe
    :return: rtn:  pandas.dataframe
    '''
    Update_col_names=[]
    for col in dataframe.columns:
        Update_col_names.append(' '.join(col))
    Update_index_names=[]
    for ind in dataframe.index:
        Update_index_names.append(' '.join(ind))
    b=dataframe.values[:,:]
    rtn=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
    return rtn

# %% [markdown]
# # Data Reading
# ## Read data also show
# The names of the data frames giving information about the table.
# Some .xlsx files has 2 tables and seconds tables are not very helpful for our tasks so just use table a for those ones: Example
# A function placed for merging the index and headders and in the code there are both function and non function methods.
# This script shows to reach data but I would suggest you to take function and use in your own script

# %%
census_data_table_1=pd.read_excel('table01.xlsx',skiprows=4,skipfooter= 7, header=[0,1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_1.name='by Sex and Single Years of Age'
census_data_table_1=merge_Ind_Col(census_data_table_1)
census_data_table_1.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                           252274.0
# BOTH SEXES 18 to 24 years                                                     28659.0
# BOTH SEXES 25 to 34 years                                                     44871.0
# BOTH SEXES 35 to 44 years                                                     41558.0
# BOTH SEXES 45 to 54 years                                                     39758.0
#
#                                     United States citizen Total citizen population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                           231593.0
# ...

# %%
census_data_table_2_1_a=pd.read_excel('table02_1.xlsx',skiprows=4,skipfooter= 41,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_1_a.Name='Table 2. Reported Voting and Registration, by Race, All Races, Sex, and Age'

census_data_table_2_1_a=merge_Ind_Col(census_data_table_2_1_a)
census_data_table_2_1_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                           252274.0
# BOTH SEXES 18 to 24 years                                                     28659.0
# BOTH SEXES 25 to 44 years                                                     86429.0
# BOTH SEXES 45 to 64 years                                                     81912.0
# BOTH SEXES 65 to 74 years                                                     32954.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                           231593.0
# ...

# %%
census_data_table_2_1_b=pd.read_excel('table02_1.xlsx',skiprows=38,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_1_b.Name='Table 2. Reported Voting and Registration, by Race, All Races, Sex, and Age'

census_data_table_2_1_b=merge_Ind_Col(census_data_table_2_1_b)
census_data_table_2_1_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              586.0
# BOTH SEXES 18 to 24 years                                                       592.0
# BOTH SEXES 25 to 44 years                                                       951.0
# BOTH SEXES 45 to 64 years                                                       897.0
# BOTH SEXES 65 to 74 years                                                       755.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             924.0
# ...

# %%
census_data_table_2_2_a=pd.read_excel('table02_2.xlsx',skiprows=4,skipfooter= 41,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_2_a.name='Table 2. Reported Voting and Registration, by Race, White , Sex, and Age'

census_data_table_2_2_a=merge_Ind_Col(census_data_table_2_2_a)
census_data_table_2_2_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                           195227.0
# BOTH SEXES 18 to 24 years                                                     20996.0
# BOTH SEXES 25 to 44 years                                                     63808.0
# BOTH SEXES 45 to 64 years                                                     64265.0
# BOTH SEXES 65 to 74 years                                                     27122.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                           181891.0
# ...

# %%
census_data_table_2_2_b=pd.read_excel('table02_2.xlsx',skiprows=38,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_2_b.name='Table 2. Reported Voting and Registration, by Race, White , Sex, and Age'

census_data_table_2_2_b=merge_Ind_Col(census_data_table_2_2_b)
census_data_table_2_2_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              885.0
# BOTH SEXES 18 to 24 years                                                       518.0
# BOTH SEXES 25 to 44 years                                                       890.0
# BOTH SEXES 45 to 64 years                                                       969.0
# BOTH SEXES 65 to 74 years                                                       936.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             970.0
# ...

# %%
census_data_table_2_3_a=pd.read_excel('table02_3.xlsx',skiprows=4,skipfooter= 41,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_3_a.name='Table 2. Reported Voting and Registration, by Race, White Not Hispanic, Sex, and Age'

census_data_table_2_3_a=merge_Ind_Col(census_data_table_2_3_a)
census_data_table_2_3_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                           157442.0
# BOTH SEXES 18 to 24 years                                                     15057.0
# BOTH SEXES 25 to 44 years                                                     47776.0
# BOTH SEXES 45 to 64 years                                                     52913.0
# BOTH SEXES 65 to 74 years                                                     24222.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                           154827.0
# ...

# %%
census_data_table_2_3_b=pd.read_excel('table02_3.xlsx',skiprows=38,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_3_b.name='Table 2. Reported Voting and Registration, by Race, White Not Hispanic, Sex, and Age'
census_data_table_2_3_b=merge_Ind_Col(census_data_table_2_3_b)
census_data_table_2_3_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              951.0
# BOTH SEXES 18 to 24 years                                                       454.0
# BOTH SEXES 25 to 44 years                                                       828.0
# BOTH SEXES 45 to 64 years                                                       964.0
# BOTH SEXES 65 to 74 years                                                       969.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             968.0
# ...

# %%
census_data_table_2_4_a=pd.read_excel('table02_4.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_4_a.name='Table 2. Reported Voting and Registration, by Race, Black, Sex, and Age'

census_data_table_2_4_a=merge_Ind_Col(census_data_table_2_4_a)
census_data_table_2_4_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                            32219.0
# BOTH SEXES 18 to 24 years                                                      4220.0
# BOTH SEXES 25 to 44 years                                                     12320.0
# BOTH SEXES 45 to 64 years                                                     10324.0
# BOTH SEXES 65 to 74 years                                                      3481.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                            30204.0
# ...

# %%
census_data_table_2_4_b=pd.read_excel('table02_4.xlsx',skiprows=38,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_4_b.name='Table 2. Reported Voting and Registration, by Race, Black, Sex, and Age'

census_data_table_2_4_b=merge_Ind_Col(census_data_table_2_4_b)
census_data_table_2_4_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              438.0
# BOTH SEXES 18 to 24 years                                                       222.0
# BOTH SEXES 25 to 44 years                                                       387.0
# BOTH SEXES 45 to 64 years                                                       435.0
# BOTH SEXES 65 to 74 years                                                       438.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             421.0
# ...

# %%
census_data_table_2_5_a=pd.read_excel('table02_5.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_5_a.name='Table 2. Reported Voting and Registration, by Race, Asian, Sex, and Age'

census_data_table_2_5_a=merge_Ind_Col(census_data_table_2_5_a)
census_data_table_2_5_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                            16094.0
# BOTH SEXES 18 to 24 years                                                      1797.0
# BOTH SEXES 25 to 44 years                                                      6617.0
# BOTH SEXES 45 to 64 years                                                      5006.0
# BOTH SEXES 65 to 74 years                                                      1655.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                            11530.0
# ...

# %%
census_data_table_2_6_a=pd.read_excel('table02_6.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_6_a.name='Table 2. Reported Voting and Registration, by Race, Hispanic or latino, Sex, and Age'

census_data_table_2_6_a=merge_Ind_Col(census_data_table_2_6_a)
census_data_table_2_6_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                            42468.0
# BOTH SEXES 18 to 24 years                                                      6769.0
# BOTH SEXES 25 to 44 years                                                     18137.0
# BOTH SEXES 45 to 64 years                                                     12598.0
# BOTH SEXES 65 to 74 years                                                      3223.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                            30627.0
# ...

# %%
census_data_table_2_6_b=pd.read_excel('table02_6.xlsx',skiprows=38,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_6_b.name='Table 2. Reported Voting and Registration, by Race, Hispanic or latino, Sex, and Age'

census_data_table_2_6_b=merge_Ind_Col(census_data_table_2_6_b)
census_data_table_2_6_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              372.0
# BOTH SEXES 18 to 24 years                                                       280.0
# BOTH SEXES 25 to 44 years                                                       409.0
# BOTH SEXES 45 to 64 years                                                       400.0
# BOTH SEXES 65 to 74 years                                                       384.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             410.0
# ...

# %%
census_data_table_2_7_a=pd.read_excel('table02_7.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_7_a.name='Table 2. Reported Voting and Registration, by Race, White Alone or in Combination, Sex, and Age'

census_data_table_2_7_a=merge_Ind_Col(census_data_table_2_7_a)
census_data_table_2_7_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                           199610.0
# BOTH SEXES 18 to 24 years                                                     21976.0
# BOTH SEXES 25 to 44 years                                                     65649.0
# BOTH SEXES 45 to 64 years                                                     65329.0
# BOTH SEXES 65 to 74 years                                                     27447.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                           185983.0
# ...

# %%
census_data_table_2_7_b=pd.read_excel('table02_7.xlsx',skiprows=38,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_7_b.name='Table 2. Reported Voting and Registration, by Race, White Alone or in Combination, Sex, and Age'
census_data_table_2_7_b.head()
Update_col_names=[]
for col in census_data_table_2_7_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_2_7_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_2_7_b.index)}
b=census_data_table_2_7_b.values[:,:]
census_data_table_2_7_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_2_7_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              870.0
# BOTH SEXES 18 to 24 years                                                       529.0
# BOTH SEXES 25 to 44 years                                                       898.0
# BOTH SEXES 45 to 64 years                                                       967.0
# BOTH SEXES 65 to 74 years                                                       927.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             969.0
# ...

# %%
census_data_table_2_8_a=pd.read_excel('table02_8.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_8_a.name='Table 2. Reported Voting and Registration, by Race, Black Alone or in Combination, Sex, and Age'
census_data_table_2_8_a.head()
Update_col_names=[]
for col in census_data_table_2_8_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_2_8_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_2_8_a.index)}
b=census_data_table_2_8_a.values[:,:]
census_data_table_2_8_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_2_8_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                            34471.0
# BOTH SEXES 18 to 24 years                                                      4784.0
# BOTH SEXES 25 to 44 years                                                     13316.0
# BOTH SEXES 45 to 64 years                                                     10808.0
# BOTH SEXES 65 to 74 years                                                      3594.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                            32275.0
# ...

# %%
census_data_table_2_8_b=pd.read_excel('table02_8.xlsx',skiprows=38,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_8_b.name='Table 2. Reported Voting and Registration, by Race, Black Alone or in Combination, Sex, and Age'
census_data_table_2_8_b.head()
Update_col_names=[]
for col in census_data_table_2_8_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_2_8_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_2_8_b.index)}
b=census_data_table_2_8_b.values[:,:]
census_data_table_2_8_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_2_8_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              435.0
# BOTH SEXES 18 to 24 years                                                       236.0
# BOTH SEXES 25 to 44 years                                                       398.0
# BOTH SEXES 45 to 64 years                                                       437.0
# BOTH SEXES 65 to 74 years                                                       438.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             427.0
# ...

# %%
census_data_table_2_9_a=pd.read_excel('table02_9.xlsx',skiprows=4,skipfooter= 42,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_9_a.name='Table 2. Reported Voting and Registration, by Race, Asian Alone or in Combination, Sex, and Age'
census_data_table_2_9_a.head()
Update_col_names=[]
for col in census_data_table_2_9_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_2_9_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_2_9_a.index)}
b=census_data_table_2_9_a.values[:,:]
census_data_table_2_9_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_2_9_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                            17273.0
# BOTH SEXES 18 to 24 years                                                      2106.0
# BOTH SEXES 25 to 44 years                                                      7207.0
# BOTH SEXES 45 to 64 years                                                      5230.0
# BOTH SEXES 65 to 74 years                                                      1693.0
#
#                                     United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total 18 years and over                                            12641.0
# ...

# %%
census_data_table_2_9_b=pd.read_excel('table02_9.xlsx',skiprows=38,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_2_9_b.name='Table 2. Reported Voting and Registration, by Race, Asian Alone or in Combination, Sex, and Age'
census_data_table_2_9_b.head()
Update_col_names=[]
for col in census_data_table_2_9_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_2_9_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_2_9_b.index)}
b=census_data_table_2_9_b.values[:,:]
census_data_table_2_9_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_2_9_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                     United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total 18 years and over                                              297.0
# BOTH SEXES 18 to 24 years                                                       148.0
# BOTH SEXES 25 to 44 years                                                       257.0
# BOTH SEXES 45 to 64 years                                                       293.0
# BOTH SEXES 65 to 74 years                                                       297.0
#
#                                     United States citizen Reported registered Number  \
# BOTH SEXES Total 18 years and over                                             279.0
# ...

# %%
census_data_table_3_a=pd.read_excel('table03.xlsx',skiprows=4,skipfooter= 103,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_3_a.name='Table 3. Reported Voting and Registration by Age, for the United States, Regions, and Divisions'
census_data_table_3_a.tail()
Update_col_names=[]
for col in census_data_table_3_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_3_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_3_a.index)}
b=census_data_table_3_a.values[:,:]
census_data_table_3_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_3_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                 Region, division and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# UNITED STATES
# NORTHEAST TOTAL                            Total 18 years and over
# NORTHEAST TOTAL                                     18 to 24 years
# NORTHEAST TOTAL                                     25 to 44 years
# NORTHEAST TOTAL                                     45 to 64 years
#
#                 Total population Unnamed: 3_level_1 Unnamed: 3_level_2  \
# UNITED STATES                                               252274
# NORTHEAST TOTAL                                              43635
# NORTHEAST TOTAL                                               4645
# NORTHEAST TOTAL                                              14524
# ...

# %%
census_data_table_3_b=pd.read_excel('table03.xlsx',skiprows=99,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_3_b.name='Table 3. Reported Voting and Registration by Age, for the United States, Regions, and Divisions'
census_data_table_3_b.tail()
Update_col_names=[]
for col in census_data_table_3_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_3_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_3_b.index)}
b=census_data_table_3_b.values[:,:]
census_data_table_3_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_3_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                 Region, division and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# UNITED STATES
# NORTHEAST TOTAL                            Total 18 years and over
# NORTHEAST TOTAL                                     18 to 24 years
# NORTHEAST TOTAL                                     25 to 44 years
# NORTHEAST TOTAL                                     45 to 64 years
#
#                 United States citizen Total Citizen Population Unnamed: 3_level_2  \
# UNITED STATES                                                  789
# NORTHEAST TOTAL                                                701
# NORTHEAST TOTAL                                                248
# NORTHEAST TOTAL                                                418
# ...

# %%
census_data_table_4a=pd.read_excel('table04a.xlsx',skiprows=4,skipfooter= 7,header=[0, 1],index_col=[0]).fillna(method='ffill')
census_data_table_4a.name='Table 4a Reported Voting and Registration, by Sex, Race and Hispanic Origin, for States'
census_data_table_4a.tail()
Update_col_names=[]
for col in census_data_table_4a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_4a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_4a.index)}
b=census_data_table_4a.values[:,:]
census_data_table_4a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_4a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                            Total population Unnamed: 1_level_1  \
# U N I T E D   S T A T E S                             252274.0
# A L A B A M A                                           3769.0
# A L A S K A                                              528.0
# A R I Z O N A                                           5638.0
# A R K A N S A S                                         2283.0
#
#                            Total citizen population Unnamed: 2_level_1  \
# U N I T E D   S T A T E S                                     231593.0
# A L A B A M A                                                   3716.0
# A L A S K A                                                      516.0
# A R I Z O N A                                                   5075.0
# ...

# %%
census_data_table_4b=pd.read_excel('table04b.xlsx',skiprows=4,skipfooter= 9,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_4b.name='Table 4b Reported Voting and Registration, by Sex, Race and Hispanic Origin, for States'
census_data_table_4b.tail()
Update_col_names=[]
for col in census_data_table_4b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_4b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_4b.index)}
b=census_data_table_4b.values[:,:]
census_data_table_4b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_4b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                             Total population Unnamed: 2_level_1  \
# US Total                                                 252274
# US Male                                                  121870
# US Female                                                130404
# US White alone                                           195227
# US White non-Hispanic alone                              157442
#
#                             Total citizen population Unnamed: 3_level_1  \
# US Total                                                         231593
# US Male                                                          111485
# US Female                                                        120108
# ...

# %%
census_data_table_4c=pd.read_excel('table04c.xlsx',skiprows=4,skipfooter= 8,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_4c.name='Table 4c Reported Voting and Registration, by Age, for States'
census_data_table_4c.tail()
Update_col_names=[]
for col in census_data_table_4c.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_4c.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_4c.index)}
b=census_data_table_4c.values[:,:]
census_data_table_4c=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_4c.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#             Total population Unnamed: 2_level_1  \
# US Total                                 252274
# US 18 to 24                               28659
# US 25 to 34                               44871
# US 35 to 44                               41558
# US 45 to 64                               81912
#
#             Total citizen population Unnamed: 3_level_1  \
# US Total                                         231593
# US 18 to 24                                       26737
# US 25 to 34                                       39962
# US 35 to 44                                       35977
# US 45 to 64                                       75590
#
#             Registered Total registered  \
# US Total                         168308
# ...

# %%
census_data_table_5_1_a=pd.read_excel('table05_1.xlsx',skiprows=4,skipfooter= 43,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_1_a.name='Table 5.  Age, Sex, and Educational Attainment 18 years and over '
census_data_table_5_1_a.tail()
Update_col_names=[]
for col in census_data_table_5_1_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_1_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_1_a.index)}
b=census_data_table_5_1_a.values[:,:]
census_data_table_5_1_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_1_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                        252274.0
# BOTH SEXES Less than 9th grade                                                            8685.0
# BOTH SEXES 9th to 12th grade, no diploma                                                 15025.0
# BOTH SEXES High school graduate                                                          73329.0
# BOTH SEXES Some college or associate's degree                                            68797.0
#
#                                                United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_5_1_b=pd.read_excel('table05_1.xlsx',skiprows=40,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_1_b.name='Table 5.  Age, Sex, and Educational Attainment 18 years and over '
census_data_table_5_1_b.tail()
Update_col_names=[]
for col in census_data_table_5_1_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_1_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_1_b.index)}
b=census_data_table_5_1_b.values[:,:]
census_data_table_5_1_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_1_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           586.0
# BOTH SEXES Less than 9th grade                                                             262.0
# BOTH SEXES 9th to 12th grade, no diploma                                                   421.0
# BOTH SEXES High school graduate                                                            854.0
# BOTH SEXES Some college or associate's degree                                              848.0
#
#                                                United States citizen Reported registered Number  \
# ...

# %%
census_data_table_5_2_a=pd.read_excel('table05_2.xlsx',skiprows=4,skipfooter= 45,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_2_a.name='Table 5.  Age, Sex, and Educational Attainment 18 to 24 years'
census_data_table_5_2_a.tail()
Update_col_names=[]
for col in census_data_table_5_2_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_2_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_2_a.index)}
b=census_data_table_5_2_a.values[:,:]
census_data_table_5_2_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_2_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                               Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           28659
# BOTH SEXES Less than 9th grade                                                               517
# BOTH SEXES 9th to 12th grade, no diploma                                                    2962
# BOTH SEXES High school graduate                                                             9951
# BOTH SEXES Some college or associate's degree                                              11586
#
#                                               United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_5_2_b=pd.read_excel('table05_2.xlsx',skiprows=42,skipfooter= 8,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_2_b.name='Table 5.  Age, Sex, and Educational Attainment 18 to 24 years'
census_data_table_5_2_b.tail()
Update_col_names=[]
for col in census_data_table_5_2_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_2_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_2_b.index)}
b=census_data_table_5_2_b.values[:,:]
census_data_table_5_2_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_2_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                               Total Citizen Population Unnamed: 2_level_1  \
# BOTH SEXES Total                                                                      592
# BOTH SEXES Less than 9th grade                                                         73
# BOTH SEXES 9th to 12th grade, no diploma                                              210
# BOTH SEXES High school graduate                                                       414
# BOTH SEXES Some college or associate's degree                                         558
#
#                                               Reported registered Number  \
# BOTH SEXES Total                                                     469
# ...

# %%
census_data_table_5_3_a=pd.read_excel('table05_3.xlsx',skiprows=4,skipfooter= 43,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_3_a.name='Table 5.  Age, Sex, and Educational Attainment 25 to 44 years'
census_data_table_5_3_a.tail()
Update_col_names=[]
for col in census_data_table_5_3_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_3_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_3_a.index)}
b=census_data_table_5_3_a.values[:,:]
census_data_table_5_3_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_3_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                         86429.0
# BOTH SEXES Less than 9th grade                                                            2299.0
# BOTH SEXES 9th to 12th grade, no diploma                                                  4231.0
# BOTH SEXES High school graduate                                                          22477.0
# BOTH SEXES Some college or associate's degree                                            21872.0
#
#                                                United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_5_3_b=pd.read_excel('table05_3.xlsx',skiprows=40,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_3_b.name='Table 5.  Age, Sex, and Educational Attainment 25 to 44 years'
census_data_table_5_3_b.tail()
Update_col_names=[]
for col in census_data_table_5_3_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_3_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_3_b.index)}
b=census_data_table_5_3_b.values[:,:]
census_data_table_5_3_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_3_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           951.0
# BOTH SEXES Less than 9th grade                                                             601.0
# BOTH SEXES 9th to 12th grade, no diploma                                                   629.0
# BOTH SEXES High school graduate                                                            771.0
# BOTH SEXES Some college or associate's degree                                              868.0
#
#                                                United States citizen Reported registered Number  \
# ...

# %%
census_data_table_5_4_a=pd.read_excel('table05_4.xlsx',skiprows=4,skipfooter= 43,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_4_a.name='Table 5.  Age, Sex, and Educational Attainment 45 to 64 years'
census_data_table_5_4_a.tail()
Update_col_names=[]
for col in census_data_table_5_4_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_4_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_4_a.index)}
b=census_data_table_5_4_a.values[:,:]
census_data_table_5_4_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_4_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                         81912.0
# BOTH SEXES Less than 9th grade                                                            3168.0
# BOTH SEXES 9th to 12th grade, no diploma                                                  4344.0
# BOTH SEXES High school graduate                                                          23601.0
# BOTH SEXES Some college or associate's degree                                            21370.0
#
#                                                United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_5_4_b=pd.read_excel('table05_4.xlsx',skiprows=40,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_4_b.name='Table 5.  Age, Sex, and Educational Attainment 45 to 64 years'
census_data_table_5_4_b.tail()
Update_col_names=[]
for col in census_data_table_5_4_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_4_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_4_b.index)}
b=census_data_table_5_4_b.values[:,:]
census_data_table_5_4_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_4_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           897.0
# BOTH SEXES Less than 9th grade                                                             953.0
# BOTH SEXES 9th to 12th grade, no diploma                                                   958.0
# BOTH SEXES High school graduate                                                            971.0
# BOTH SEXES Some college or associate's degree                                              958.0
#
#                                                United States citizen Reported registered Number  \
# ...

# %%
census_data_table_5_5_a=pd.read_excel('table05_5.xlsx',skiprows=4,skipfooter= 43,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_5_a.name='Table 5.  Age, Sex, and Educational Attainment 65 to 74 years'
census_data_table_5_5_a.head()
Update_col_names=[]
for col in census_data_table_5_5_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_5_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_5_a.index)}
b=census_data_table_5_5_a.values[:,:]
census_data_table_5_5_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_5_a.head()

census_data_table_5_5_b=pd.read_excel('table05_5.xlsx',skiprows=40,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_5_b.name='Table 5.  Age, Sex, and Educational Attainment 65 to 74 years'
census_data_table_5_5_b.head()
Update_col_names=[]
for col in census_data_table_5_5_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_5_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_5_b.index)}
b=census_data_table_5_5_b.values[:,:]
census_data_table_5_5_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_5_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           755.0
# BOTH SEXES Less than 9th grade                                                             894.0
# BOTH SEXES 9th to 12th grade, no diploma                                                   889.0
# BOTH SEXES High school graduate                                                            855.0
# ...

# %%
census_data_table_5_6_a=pd.read_excel('table05_6.xlsx',skiprows=4,skipfooter= 43,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_6_a.name='Table 5.  Age, Sex, and Educational Attainment 75 years and over'
census_data_table_5_6_a.head()
Update_col_names=[]
for col in census_data_table_5_6_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_6_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_6_a.index)}
b=census_data_table_5_6_a.values[:,:]
census_data_table_5_6_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_6_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                         22320.0
# BOTH SEXES Less than 9th grade                                                            1380.0
# BOTH SEXES 9th to 12th grade, no diploma                                                  1705.0
# BOTH SEXES High school graduate                                                           7857.0
# BOTH SEXES Some college or associate's degree                                             5069.0
#
#                                                United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_5_6_b=pd.read_excel('table05_6.xlsx',skiprows=40,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_5_6_b.name='Table 5.  Age, Sex, and Educational Attainment 75 years and over'
census_data_table_5_6_b.head()
Update_col_names=[]
for col in census_data_table_5_6_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_5_6_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_5_6_b.index)}
b=census_data_table_5_6_b.values[:,:]
census_data_table_5_6_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_5_6_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                                United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                                           586.0
# BOTH SEXES Less than 9th grade                                                             748.0
# BOTH SEXES 9th to 12th grade, no diploma                                                   737.0
# BOTH SEXES High school graduate                                                            683.0
# BOTH SEXES Some college or associate's degree                                              643.0
#
#                                                United States citizen Reported registered Number  \
# ...

# %%
census_data_table_6_a=pd.read_excel('table06.xlsx',skiprows=4,skipfooter= 52,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_6_a.name='Table 6. Class of Worker and Disability Status'
census_data_table_6_a.tail()
Update_col_names=[]
for col in census_data_table_6_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_6_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_6_a.index)}
b=census_data_table_6_a.values[:,:]
census_data_table_6_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_6_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                  Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                                                          252274.0
# BOTH SEXES Not in labor force                                              93172.0
# BOTH SEXES Civilian labor force                                           159102.0
# BOTH SEXES Government Workers                                              20763.0
# BOTH SEXES Private Industry                                               118864.0
#
#                                  United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total                                                          231593.0
# ...

# %%
census_data_table_6_b=pd.read_excel('table06.xlsx',skiprows=49,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_6_b.name='Table 6. Class of Worker and Disability Status'
census_data_table_6_b.tail()
Update_col_names=[]
for col in census_data_table_6_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_6_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_6_b.index)}
b=census_data_table_6_b.values[:,:]
census_data_table_6_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_6_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                  United States citizen Total Citizen Population Unnamed: 2_level_2  \
# BOTH SEXES Total                                                             586.0
# BOTH SEXES Not in labor force                                                918.0
# BOTH SEXES Civilian labor force                                              964.0
# BOTH SEXES Government Workers                                                521.0
# BOTH SEXES Private Industry                                                  957.0
#
#                                  United States citizen Reported registered Number  \
# BOTH SEXES Total                                                            924.0
# ...

# %%
census_data_table_7_a=pd.read_excel('table07.xlsx',skiprows=4,skipfooter= 96,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_7_a.name='Table 7. Family Members, by Age and Family Income'
census_data_table_7_a.tail()
Update_col_names=[]
for col in census_data_table_7_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_7_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_7_a.index)}
b=census_data_table_7_a.values[:,:]
census_data_table_7_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_7_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                       Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# 18 YEARS AND OVER Total                                                        180221.0
# 18 YEARS AND OVER Under $10,000                                                  3083.0
# 18 YEARS AND OVER $10,000 to $14,999                                             3359.0
# 18 YEARS AND OVER $15,000 to $19,999                                             3327.0
# 18 YEARS AND OVER $20,000 to $29,999                                             9142.0
#
#                                       United States citizen Total Citizen Population Unnamed: 3_level_2  \
# 18 YEARS AND OVER Total                                                        164884.0
# ...

# %%
census_data_table_7_b=pd.read_excel('table07.xlsx',skiprows=92,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_7_b.name='Table 7. Family Members, by Age and Family Income'
census_data_table_7_b.tail()
Update_col_names=[]
for col in census_data_table_7_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_7_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_7_b.index)}
b=census_data_table_7_b.values[:,:]
census_data_table_7_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_7_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                       United States citizen Total Citizen Population Unnamed: 2_level_2  \
# 18 YEARS AND OVER Total                                                           932.0
# 18 YEARS AND OVER Under $10,000                                                   193.0
# 18 YEARS AND OVER $10,000 to $14,999                                              200.0
# 18 YEARS AND OVER $15,000 to $19,999                                              203.0
# 18 YEARS AND OVER $20,000 to $29,999                                              332.0
#
#                                       United States citizen Reported registered Number  \
# 18 YEARS AND OVER Total                                                          970.0
# ...

# %%
census_data_table_8=pd.read_excel('table08.xlsx',skiprows=4,skipfooter= 66,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_8.name='Table 8. by Duration of Residence, and Tenure'
census_data_table_8.tail()
Update_col_names=[]
for col in census_data_table_8.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_8.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_8.index)}
b=census_data_table_8.values[:,:]
census_data_table_8=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_8.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                              Total population Unnamed: 2_level_1 Unnamed: 2_level_2  \
# IN ALL OCCUPIED UNITS Duration of residence                                           252274.0
# IN ALL OCCUPIED UNITS Less than 1 year                                                 23296.0
# IN ALL OCCUPIED UNITS 1 to 2 years                                                     27654.0
# IN ALL OCCUPIED UNITS 3 to 4 years                                                     28049.0
# IN ALL OCCUPIED UNITS 5 years or longer                                               117495.0
#
#                                              United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ...

# %%
census_data_table_9_a=pd.read_excel('table09.xlsx',skiprows=4,skipfooter= 149,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_9_a.name='Table 9. by Marital Status, Age, and Sex'
census_data_table_9_a.tail()
Update_col_names=[]
for col in census_data_table_9_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_9_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_9_a.index)}
b=census_data_table_9_a.values[:,:]
census_data_table_9_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_9_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                               Marital status, sex, and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# ALL MARITAL STATUS BOTH SEXES                            Total 18 years and over
# ALL MARITAL STATUS BOTH SEXES                                     18 to 24 years
# ALL MARITAL STATUS BOTH SEXES                                     25 to 44 years
# ALL MARITAL STATUS BOTH SEXES                                     45 to 64 years
# ALL MARITAL STATUS BOTH SEXES                                     65 to 74 years
#
#                               Total population Unnamed: 3_level_1 Unnamed: 3_level_2  \
# ALL MARITAL STATUS BOTH SEXES                                             252274
# ...

# %%
census_data_table_9_b=pd.read_excel('table09.xlsx',skiprows=145,skipfooter= 8,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_9_b.name='Table 9. by Marital Status, Age, and Sex'
census_data_table_9_b.tail()
Update_col_names=[]
for col in census_data_table_9_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_9_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_9_b.index)}
b=census_data_table_9_b.values[:,:]
census_data_table_9_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_9_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                               Marital status, sex, and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# ALL MARITAL STATUS BOTH SEXES                            Total 18 years and over
# ALL MARITAL STATUS BOTH SEXES                                     18 to 24 years
# ALL MARITAL STATUS BOTH SEXES                                     25 to 44 years
# ALL MARITAL STATUS BOTH SEXES                                     45 to 64 years
# ALL MARITAL STATUS BOTH SEXES                                     65 to 74 years
#
#                               United States citizen Total Citizen Population Unnamed: 3_level_2  \
# ALL MARITAL STATUS BOTH SEXES                                                586
# ...

# %%
census_data_table_10_a=pd.read_excel('table10.xlsx',skiprows=4,skipfooter= 66,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_10_a.name='Table 10. Reasons For Not Voting, By Selected Characteristics'
census_data_table_10_a.tail()
Update_col_names=[]
for col in census_data_table_10_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_10_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_10_a.index)}
b=census_data_table_10_a.values[:,:]
census_data_table_10_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_10_a.tail()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                      Total not voting1  Unnamed: 2_level_1  \
# Family income2  $50,000 to $74,999                                    1435
# Family income2  $75,000 to $99,999                                     964
# Family income2  $100,000 to $149,999                                   989
# Family income2  $150,000 and over                                      752
# Family income2  Income not reported                                   1339
#
#                                      Percent distribution of reasons for not voting Out of town  \
# Family income2  $50,000 to $74,999                                                  5.7
# Family income2  $75,000 to $99,999                                                  8.6
# ...

# %%
census_data_table_10_b=pd.read_excel('table10.xlsx',skiprows=61,skipfooter= 9,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_10_b.name='Table 10. Reasons For Not Voting, By Selected Characteristics'
census_data_table_10_b.tail()
Update_col_names=[]
for col in census_data_table_10_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_10_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_10_b.index)}
b=census_data_table_10_b.values[:,:]
census_data_table_10_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_10_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                       Margins of error for distribution of reasons for not voting Out of town  \
# TOTAL                                                                0.8
# Age 18 to 24 years                                                   2.4
# Age 25 to 44 years                                                   1.2
# Age 45 to 64 years                                                   1.6
# Age 65 years and over                                                1.6
#
#                       Margins of error for distribution of reasons for not voting Forgot to vote  \
# TOTAL                                                                0.6
# Age 18 to 24 years                                                     2
# ...

# %%
census_data_table_11_a=pd.read_excel('table11.xlsx',skiprows=4,skipfooter= 56,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_11_a.name='Table 11. Native and Naturalized Citizens, by Race, and Region of Origin'
census_data_table_11_a.head()
Update_col_names=[]
for col in census_data_table_11_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_11_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_11_a.index)}
b=census_data_table_11_a.values[:,:]
census_data_table_11_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_11_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                         United States citizen Total Citizen Population Unnamed: 2_level_2  \
# United States All races                                                          231593.0
# United States White alone                                                        181891.0
# United States White non-Hispanic alone                                           154827.0
# United States Black alone                                                         30204.0
# United States Asian alone                                                         11530.0
#
#                                         United States citizen Reported registered Number  \
# United States All races                                                         168308.0
# ...

# %%
census_data_table_11_b=pd.read_excel('table11.xlsx',skiprows=53,skipfooter= 7,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_11_b.name='Table 11. Native and Naturalized Citizens, by Race, and Region of Origin'
census_data_table_11_b.tail()
Update_col_names=[]
for col in census_data_table_11_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_11_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_11_b.index)}
b=census_data_table_11_b.values[:,:]
census_data_table_11_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_11_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                                         United States citizen Total Citizen Population Unnamed: 2_level_2  \
# United States All races                                                             586.0
# United States White alone                                                           885.0
# United States White non-Hispanic alone                                              951.0
# United States Black alone                                                           625.0
# United States Asian alone                                                           402.0
#
#                                         United States citizen Reported registered Number  \
# United States All races                                                            924.0
# ...

# %%
census_data_table_12_a=pd.read_excel('table12.xlsx',skiprows=4,skipfooter= 62,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_12_a.name='Table 12.  Method of Registration, By Selected Characteristics'
census_data_table_12_a.tail()
Update_col_names=[]
for col in census_data_table_12_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_12_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_12_a.index)}
b=census_data_table_12_a.values[:,:]
census_data_table_12_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_12_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                        Total registered1  Unnamed: 2_level_1  \
# TOTAL                                               168308.0
# Age 18 to 24 years                                   15984.0
# Age 25 to 44 years                                   53203.0
# Age 45 to 64 years                                   57226.0
# Age 65 years and over                                41895.0
#
#                        Percent distribution of methods of registration At department of motor vehicles  \
# TOTAL                                                               27.7
# Age 18 to 24 years                                                  28.1
# Age 25 to 44 years                                                  32.0
# ...

# %%
census_data_table_12_b=pd.read_excel('table12.xlsx',skiprows=59,skipfooter= 7,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_12_b.name='Table 12.  Method of Registration, By Selected Characteristics'
census_data_table_12_b.head()
Update_col_names=[]
for col in census_data_table_12_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_12_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_12_b.index)}
b=census_data_table_12_b.values[:,:]
census_data_table_12_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_12_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                        Percent distribution of methods of registration At department of motor vehicles  \
# TOTAL                                                                0.4
# Age 18 to 24 years                                                   1.4
# Age 25 to 44 years                                                   0.8
# Age 45 to 64 years                                                   0.7
# Age 65 years and over                                                0.7
#
#                        Percent distribution of methods of registration At public assistance agency  \
# TOTAL                                                                0.1
# Age 18 to 24 years                                                   0.3
# ...

# %%
census_data_table_13_a=pd.read_excel('table13.xlsx',skiprows=4,skipfooter= 83,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_13_a.name='Table 13. Reported Voting and Registration, by Sex, Veteran Status, and Age'
census_data_table_13_a.tail()
Update_col_names=[]
for col in census_data_table_13_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_13_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_13_a.index)}
b=census_data_table_13_a.values[:,:]
census_data_table_13_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_13_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                  Sex, veteran status, and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                            Total 18 years and over
# BOTH SEXES Total                                     18 to 24 years
# BOTH SEXES Total                                     25 to 44 years
# BOTH SEXES Total                                     45 to 64 years
# BOTH SEXES Total                                     65 to 74 years
#
#                  Total population Unnamed: 3_level_1 Unnamed: 3_level_2  \
# BOTH SEXES Total                                             252269
# BOTH SEXES Total                                              28654
# BOTH SEXES Total                                              86429
# ...

# %%
census_data_table_13_b=pd.read_excel('table13.xlsx',skiprows=76,skipfooter= 11,header=[0, 1,2],index_col=[0,1]).fillna(method='ffill')
census_data_table_13_b.name='Table 13. Reported Voting and Registration, by Sex, Veteran Status, and Age'
census_data_table_13_b.tail()
Update_col_names=[]
for col in census_data_table_13_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_13_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_13_b.index)}
b=census_data_table_13_b.values[:,:]
census_data_table_13_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_13_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                  Sex, veteran status, and age Unnamed: 2_level_1 Unnamed: 2_level_2  \
# BOTH SEXES Total                            Total 18 years and over
# BOTH SEXES Total                                     18 to 24 years
# BOTH SEXES Total                                     25 to 44 years
# BOTH SEXES Total                                     45 to 64 years
# BOTH SEXES Total                                     65 to 74 years
#
#                  United States citizen Total Citizen Population Unnamed: 3_level_2  \
# BOTH SEXES Total                                                585
# BOTH SEXES Total                                                592
# BOTH SEXES Total                                                951
# ...

# %%
census_data_table_14_a=pd.read_excel('table14.xlsx',skiprows=4,skipfooter= 58,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_14_a.name='Table 14.  Method of Voting, By Selected Characteristics'
census_data_table_14_a.tail()
Update_col_names=[]
for col in census_data_table_14_a.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_14_a.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_14_a.index)}
b=census_data_table_14_a.values[:,:]
census_data_table_14_a=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_14_a.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                        Total voted Unnamed: 2_level_1  \
# TOTAL                                        154628.0
# Age 18 to 24 years                            13752.0
# Age 25 to 44 years                            47512.0
# Age 45 to 64 years                            53646.0
# Age 65 years and over                         39718.0
#
#                        Percent distribution of methods of voting In-person on Election Day  \
# TOTAL                                                               30.4
# Age 18 to 24 years                                                  35.1
# Age 25 to 44 years                                                  34.2
# Age 45 to 64 years                                                  31.8
# ...

# %%
census_data_table_14_b=pd.read_excel('table14.xlsx',skiprows=57,skipfooter= 5,header=[0, 1],index_col=[0,1]).fillna(method='ffill')
census_data_table_14_b.name='Table 14.  Method of Voting, By Selected Characteristics'
census_data_table_14_b.tail()
Update_col_names=[]
for col in census_data_table_14_b.columns:
    Update_col_names.append(' '.join(col))
Update_index_names=[]
for ind in census_data_table_14_b.index:
    Update_index_names.append(' '.join(ind))
index_dic={map(Update_index_names,census_data_table_14_b.index)}
b=census_data_table_14_b.values[:,:]
census_data_table_14_b=pd.DataFrame(b,columns=Update_col_names,index=Update_index_names)
census_data_table_14_b.head()
# Out:
# c:\Users\mbagci\Anaconda3\envs\myenv\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                        Percent distribution of methods of voting In-person on Election Day  \
# TOTAL                                                                0.4
# Age 18 to 24 years                                                   1.6
# Age 25 to 44 years                                                   0.8
# Age 45 to 64 years                                                   0.8
# Age 65 years and over                                                0.8
#
#                        Percent distribution of methods of voting In-person Before Election Day  \
# TOTAL                                                                0.4
# Age 18 to 24 years                                                   1.4
# ...
